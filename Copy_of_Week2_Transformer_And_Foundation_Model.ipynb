# %% [markdown]
# Transformer And Foundation Models of VertexAI:

# %% [markdown]
# - What is Transformer?
# - How is it Used?
# - What is foundation model?

# %% [markdown]
# What is transformer? [Huggingface transformer Tour](https://huggingface.co/docs/transformers/quicktour)
# - Developed by Google researchers in 2017
# - Provide an alternative to traditional recurrent neural networks (RNNs) and convolutional neural networks (CNNs) to handle sequential data, namely text.
# - An architecture of neural networks that takes a text sequence as input and produces another text sequence as output.
# - Understand the interplay of words in a sentence, capturing context.
# - State-of-the-art Machine Learning for PyTorch, TensorFlow, and JAX.
# - Provides APIs and tools to easily download and train state-of-the-art pretrained models.
# - Use of pretained models reduces cost of computation,carbon footprint, and save you the time and resources required to train a model from scratch.
# - These models support common tasks in different modalities like
#    - Natural Language Processing :
#       - text classification, named entity recognition, question answering, language modeling, summarization, translation, multiple choice, and text generation.
#    - 🖼️ Computer Vision:
#       - image classification, object detection, and segmentation.
#    - 🗣️ Audio:
#       -  automatic speech recognition and audio classification.
#    - 🐙 Multimodal:
#       - table question answering, optical character recognition, information extraction from scanned documents, video classification, and visual question answering.

# %% [markdown]
# Transformer Architecture:
# - Transformer models are neural networks
# - It has high-level architecture which uses an encoder and decoder
# - The encoder takes the input data and is able to extract meaning and context from the data and pass onto the decoder
# - This is performed by converting the input sequence into numbers called embeddings
# - Embedding is performred by mechanism called **Self Attention**,sent through  feed forward network,through normalization layer.
# - Self-Attention mechanism captures importance of each word and the relationships between the words.
# - Example,each person pays attention to everyone else's ideas. They consider the relevance, importance of each party idea and how the ideas all relate to each other. This happens as part of a brainstorming and collaboration session.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Encoder:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Attention:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Decoder:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Training transformers involves two steps:
# - pretraining
#    - Trained on large amounts of raw (text) data, with the internet as the primary data source.
#    - The training is done using self-supervised learning, an innovative type of training that doesn’t require human action to label data.
#    - The goal of **pre-training is to learn the statistical patterns of the language.**
# - fine-tuning
#   - **Trained on a narrower, domain-specific dataset **generated with the help of human reviewers following certain guidelines.

# %% [markdown]
# Foundation Models:
# - Trained on massive datasets
# - Large deep learning neural networks that have changed the way data scientists approach machine learning (ML)
# - Rather than develop artificial intelligence (AI) from scratch, data scientists use a foundation model as a starting point to develop ML models that power new applications more quickly and cost-effectively.
# - Trained on a broad spectrum of generalized and unlabeled data and capable of performing a wide variety of general tasks such as understanding language, generating text and images, and conversing in natural language.
# - Use as base models for developing more specialized downstream applications.

# %% [markdown]
# Why is foundation modeling important?
# - Although it currently costs millions of dollars to develop a foundation model from scratch, they’re useful in the long run.
# - Faster and cheaper for data scientists to use pre-trained FMs to develop new ML applications rather than train unique ML models from the ground up.
# -  Useful in automating tasks and processes, especially those that require reasoning capabilities.

# %% [markdown]
# Applications for foundation models:
# - Customer support
# - Language translation
# - Content generation
# - Copywriting
# - Image classification
# - High-resolution image creation and editing
# - Document extraction
# - Robotics
# - Healthcare
# - Autonomous vehicles

# %% [markdown]
# How do foundation models work?
# - Generate output from one or more inputs (prompts) in the form of human language instructions
# - Models are based on complex neural networks including generative adversarial networks (GANs), transformers, and variational encoders.
# - FM uses learned patterns and relationships to predict the next item in a sequence.
# - Uses self-supervised learning to create labels from input data.

# %% [markdown]
# Examples:
# - With image generation, the model analyzes the image and creates a sharper, more clearly defined version of the image.
# - With text, the model predicts the next word in a string of text based on the previous words and its context. It then selects the next word using probability distribution techniques.

# %% [markdown]
# What can foundation models do?
# - Language processing
# - Visual comprehension
# - Code generation
# - Human-centered engagement
# - Speech to text

# %% [markdown]
# Examples Of Foundation Models:
# - BERT
# - GPT
# - Amazon Titan
# - AI21 Jurassic
# - Gemini
# - Palm
# - Claude
# - Cohere
# - Stable Diffusion,etc

# %% [markdown]
# Foundation Model in VertexAI:
# - Gemini API: Advanced reasoning, multiturn chat, code generation, and multimodal prompts.
# - PaLM API: Natural language tasks, text embeddings, and multiturn chat.
# - Codey APIs: Code generation, code completion, and code chat.
# - Imagen API: Image generation, image editing, and visual captioning.
# - MedLM: Medical question answering and summarization.

# %% [markdown]
# Model customization:
# - You can customize the default behavior of Google's foundation models so that they consistently generate the desired results without using complex prompts.

# %% [markdown]
# #Tuning and deploy a foundation model

# %% [markdown]
# Tune foundation models:
# - Model tuning works by providing a model with a training dataset that contains many examples of a unique task
# - For unique, niche tasks, you can get significant improvements in model performance by tuning the model on a modest number of examples.
# - After you tune a model, fewer examples are required in its prompts.
# - Model tunning Methods supported by VertexAI:
#   - Supervised tuning
#   - Reinforcement learning from human feedback (RLHF) tuning
#   - Tuning and distillation

# %% [markdown]
# Supervised Tuning:
# - Improves the performance of a model by teaching it a new skill
# - Data that contains hundreds of labeled examples is used to teach the model to mimic a desired behavior or task
# - The output of the tuning job is a new model that combines the newly learned parameters with the original model

# %% [markdown]
# Models that support supervised tuning:
# - Text generation - text-bison@002 and text-bison-32k
# - Text chat - chat-bison@002 and chat-bison-32k
# - Code generation - code-bison@002 and code-bison-32k
# - Code chat - codechat-bison@002 and codechat-bison-32k
# - Text embeddings - textembedding-gecko@001

# %% [markdown]
# Workflow for supervised model tuning:
# - Prepare your model tuning dataset.
# - Upload the model tuning dataset to a Cloud Storage bucket.
# - Create a supervised model tuning job.

# %% [markdown]
# 1.Prepare a supervised tuning dataset:

# %% [markdown]
# Dataset format:
# - Must be in JSON Lines (JSONL) format,where each line contains a single tuning example
# - The dataset format used to tune a text generation model is different from the dataset format for tuning a text chat model
# - Before tuning your model, you must upload your dataset to a Cloud Storage bucket.
# - Each example is composed of an **input_text** field that contains **the prompt** to the model and an **output_text** field that contains an **example response** that the tuned model is expected to produce.

# %% [markdown]
# {"input_text": "question: How many people live in Beijing? context: With over 21 million residents, Beijing is the world's most populous national capital city and is China's second largest city after Shanghai. It is located in Northern China, and is governed as a municipality under the direct administration of the State Council with 16 urban, suburban, and rural districts.[14] Beijing is mostly surrounded by Hebei Province with the exception of neighboring Tianjin to the southeast; together, the three divisions form the Jingjinji megalopolis and the national capital region of China.", "output_text": "over 21 million people"}
# {"input_text": "question: How many parishes are there in Louisiana? context: The U.S. state of Louisiana is divided into 64 parishes (French: paroisses) in the same manner that 48 other states of the United States are divided into counties, and Alaska is divided into boroughs.", "output_text": "64"}

# %% [markdown]
# - Include instructions in examples

# %% [markdown]
# Excludes instructions:
# - {"input_text": "5 stocks to buy now",
# "output_text": "business"}
#
# Include instruction:
# - {"input_text": "Classify the following text into one of the following classes:
# [business, entertainment] Text: 5 stocks to buy now",
# "output_text": "business"}

# %%
# !pip install --upgrade google-cloud-aiplatform
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 22.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-cloud-aiplatform
#     Found existing installation: google-cloud-aiplatform 1.39.0
#     Uninstalling google-cloud-aiplatform-1.39.0:
#       Successfully uninstalled google-cloud-aiplatform-1.39.0
# ...

# %%
from google.cloud import aiplatform

# %%
def init_sample(
     project= None, #optional[str]
     location= None,#optional[str]
     experiment= None,#optional[str]
     staging_bucket = None,#optional[str]
     credentials= None,             #Optional[auth_credentials.Credentials]
     encryption_spec_key_name= None,
     service_account= None,#optional[str]
):

    from google.cloud import aiplatform

    aiplatform.init(
        project=project,
        location=location,
        experiment=experiment,
        staging_bucket=staging_bucket,
        credentials=credentials,
        encryption_spec_key_name=encryption_spec_key_name,
        service_account=service_account,
    )

# %%
# To install the Python SDK, use this CLI command:
# pip install google-generativeai

import vertexai
from vertexai.preview.generative_models import GenerativeModel, Image

#PROJECT_ID = "acd-genai-curriculm"
PROJECT_ID="scholastic-genai"
REGION = "us-central1"
vertexai.init(project=PROJECT_ID, location=REGION)

# %%
# Set the project id
! gcloud config set project {PROJECT_ID}
# Out:
# Updated property [core/project].

# %%
#authenticate projectid
from google.colab import auth
auth.authenticate_user(PROJECT_ID)

# %%
from vertexai.preview.generative_models import GenerativeModel, Part,Content
from IPython.display import display
from IPython.display import Markdown
from vertexai.language_models import TextGenerationModel

# %%
model = GenerativeModel("gemini-pro")

# %%
response = model.generate_content("What is the meaning of life?")

# %%
# !ls
# Out:
# sample_data  vaccinereviewTest.jsonl  vaccinereviewTrain.jsonl	vaccines-sentiment-analysis

# %%
# !pip install opendatasets

# %%
import opendatasets as od
import torch

# %%
vaccine_url="https://www.kaggle.com/datasets/gauravduttakiit/vaccines-sentiment-analysis"
od.download(vaccine_url,force=True)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: kirtikamerkar
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 3.33M/3.33M [00:00<00:00, 176MB/s]

# %%
from pathlib import Path
import pandas as pd
import torch
pd.set_option('display.max_colwidth', 1)
from torch.utils.data import Dataset, DataLoader
def read_vaccine_split(split_dir):
    split_dir = Path(split_dir)
    texts = []
    labels = []
    for label_dir in ['-1.0','0.0','1.0']:
        for text_file in (split_dir/label_dir).iterdir():
            texts.append(text_file.read_text())
            if  label_dir == "0.0":
                labels.append(0.0 )
            elif  label_dir == "-1.0":
                labels.append(-1.0)
            else :
                labels.append(1.0)

    return texts, labels

train_texts, train_labels = read_vaccine_split('/content/vaccines-sentiment-analysis/train')
test_texts, test_labels = read_vaccine_split('/content/vaccines-sentiment-analysis/test')

# %%
train=pd.DataFrame(list(zip(train_texts,train_labels)),columns=["text",'label'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    7999 non-null   object
#  1   label   7999 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 125.1+ KB

# %%
train.head()
# Out:
#                                                                                              text  \
# 0  the health department lame af talking bout be wise immunize lol
# 1  user why we didnt vaccinate our child\n\nurl so much truth
# 2  user 60 lab studies now confirm cancer link to a vaccine you probably had as a child url
# 3  user user user then you vaccinate your kids and leave ours alone
# 4  vactruthorg launches school school vaccination optout campaign no shots no school not true url
#
#    label
# 0 -1.0
# 1 -1.0
# 2 -1.0
# 3 -1.0
# 4 -1.0

# %%
def to_sentiment(label):
    label = int(label)
    if label == -1:
      return "Neutral"
    elif label == 0:
      return "Positive"
    else:
      return "Negative"

# %%
train['label']=train['label'].astype(int)
train['sentiment'] = train.label.apply(to_sentiment)
train=train.drop(columns='label')
# train['label']=train['sentiment']
# train=train.drop(columns='sentiment')

# %%
train.head()
# Out:
#                                                                                              text  \
# 0  the health department lame af talking bout be wise immunize lol
# 1  user why we didnt vaccinate our child\n\nurl so much truth
# 2  user 60 lab studies now confirm cancer link to a vaccine you probably had as a child url
# 3  user user user then you vaccinate your kids and leave ours alone
# 4  vactruthorg launches school school vaccination optout campaign no shots no school not true url
#
#   sentiment
# 0  Neutral
# 1  Neutral
# 2  Neutral
# 3  Neutral
# 4  Neutral

# %%
test=pd.DataFrame(list(zip(test_texts,test_labels)),columns=["text",'label'])

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2000 non-null   object
#  1   label   2000 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 31.4+ KB

# %%
test.head()
# Out:
#                                                                                                                             text  \
# 0  in 198514 students in corpus christi tx contracted measlesall had been vaccinated 99 of their classmates were also vaccinated
# 1  the government is spreading ebola to create fear and cause people to get vaccines which will do more harm youve been warned
# 2  apparently there are no studies which show vaccines are safe for infants especially the amount they receive
# 3  heads up if you havent got your measles vaccine
# 4  i think it is bullshit ny schools are requiring flu vaccinations whoever is in charge of that one is an asshole
#
#    label
# 0 -1.0
# 1 -1.0
# 2 -1.0
# 3 -1.0
# 4 -1.0

# %%
test['label']=test['label'].astype(int)
test['sentiment'] =test.label.apply(to_sentiment)
test=test.drop(columns='label')
# test['label']=test['sentiment']
# test=test.drop(columns='sentiment')

# %%
test.head()
# Out:
#                                                                                                                             text  \
# 0  in 198514 students in corpus christi tx contracted measlesall had been vaccinated 99 of their classmates were also vaccinated
# 1  the government is spreading ebola to create fear and cause people to get vaccines which will do more harm youve been warned
# 2  apparently there are no studies which show vaccines are safe for infants especially the amount they receive
# 3  heads up if you havent got your measles vaccine
# 4  i think it is bullshit ny schools are requiring flu vaccinations whoever is in charge of that one is an asshole
#
#   sentiment
# 0  Neutral
# 1  Neutral
# 2  Neutral
# 3  Neutral
# 4  Neutral

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x=train["sentiment"])
plt.xlabel('review sentiment');

# %% [markdown]
# Data format to tune model:
# - {"input_text": "Classify the following text into one of the following classes: [business, entertainment] Text: 5 stocks to buy now", "output_text": "business"}

# %% [markdown]
# Preparing required Dataformat for tune model and convert into jsonl/json form:

# %%
def get_input_text(text):
  input_text=f'Classify the sentiment of the following reviews  as positive, negative, or neutral towards vaccine.text:{text}'
  return input_text

# %%
get_input_text("because maybe vaccines do cause measles nationwide")
# Out:
# 'Classify the sentiment of the following reviews  as positive, negative, or neutral towards vaccine.text:because maybe vaccines do cause measles nationwide'

# %%
get_input_text(train['text'][0])
# Out:
# 'Classify the sentiment of the following reviews  as positive, negative, or neutral towards vaccine.text:the health department lame af talking bout be wise immunize lol'

# %%
train["input_text"]=train.text.apply(get_input_text)

# %%
train.head(2)
# Out:
#                                                               text sentiment  \
# 0  the health department lame af talking bout be wise immunize lol  Neutral
# 1  user why we didnt vaccinate our child\n\nurl so much truth       Neutral
#
#                                                                                                                                                                 input_text
# 0  Classify the sentiment of the following reviews  as positive, negative, or neutral towards vaccine.text:the health department lame af talking bout be wise immunize lol
# 1  Classify the sentiment of the following reviews  as positive, negative, or neutral towards vaccine.text:user why we didnt vaccinate our child\n\nurl so much truth

# %%
train['output_text']=train['sentiment']

# %%
train_df=train[['input_text','output_text']]

# %%
train_df.head(2)
# Out:
#                                                                                                                                                                 input_text  \
# 0  Classify the sentiment of the following reviews  as positive, negative, or neutral towards vaccine.text:the health department lame af talking bout be wise immunize lol
# 1  Classify the sentiment of the following reviews  as positive, negative, or neutral towards vaccine.text:user why we didnt vaccinate our child\n\nurl so much truth
#
#   output_text
# 0  Neutral
# 1  Neutral

# %%
train_df.to_json("vaccinereviewTrain.jsonl", orient='records', lines=True)

# %% [markdown]
# Preparing Test Data:

# %%
test["input_text"]=test.text.apply(get_input_text)

# %%
test['output_text']=test['sentiment']

# %%
test.head(2)
# Out:
#                                                                                                                             text  \
# 0  in 198514 students in corpus christi tx contracted measlesall had been vaccinated 99 of their classmates were also vaccinated
# 1  the government is spreading ebola to create fear and cause people to get vaccines which will do more harm youve been warned
#
#   sentiment  \
# 0  Neutral
# 1  Neutral
#
#                                                                                                                                                                                                                               input_text  \
# 0  Classify the sentiment of the following reviews  as positive, negative, or neutral towards vaccine.text:in 198514 students in corpus christi tx contracted measlesall had been vaccinated 99 of their classmates were also vaccinated
# ...

# %%
test_df=test[['input_text','output_text']]

# %%
test_df.head(2)
# Out:
#                                                                                                                                                                                                                               input_text  \
# 0  Classify the sentiment of the following reviews  as positive, negative, or neutral towards vaccine.text:in 198514 students in corpus christi tx contracted measlesall had been vaccinated 99 of their classmates were also vaccinated
# 1  Classify the sentiment of the following reviews  as positive, negative, or neutral towards vaccine.text:the government is spreading ebola to create fear and cause people to get vaccines which will do more harm youve been warned
#
#   output_text
# 0  Neutral
# 1  Neutral

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   input_text   2000 non-null   object
#  1   output_text  2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %%
test_df=test_df.head(256)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   input_text   256 non-null    object
#  1   output_text  256 non-null    object
# dtypes: object(2)
# memory usage: 4.1+ KB

# %%
test_df.to_json("vaccinereviewTest.jsonl", orient='records', lines=True)

# %% [markdown]
# Loading Data to Google cloud bucket:

# %%
#shell_output=!gcloud auth list 2>/dev/null

# %%
#SERVICE_ACCOUNT = shell_output[2].replace("*", "").strip()

# %%
import sys

IS_COLAB = "google.colab" in sys.modules
if (
    SERVICE_ACCOUNT == ""
    or SERVICE_ACCOUNT is None
    or SERVICE_ACCOUNT == "[kirti@austincapitaldata.com]"
):
    # Get your service account from gcloud
    if not IS_COLAB:
        shell_output = !gcloud auth list 2>/dev/null
        SERVICE_ACCOUNT = shell_output[2].replace("*", "").strip()

    else:  # IS_COLAB:
        shell_output = ! gcloud projects describe $PROJECT_ID --format="value(projectNumber)"
        project_number = shell_output[0]
        SERVICE_ACCOUNT = f"{project_number}-compute@developer.gserviceaccount.com"

    print("Service Account:", SERVICE_ACCOUNT)

# %%
print(SERVICE_ACCOUNT)
# Out:
# kirti@austincapitaldata.com

# %%
#BUCKET_URI="gs://scholastic-genai"
BUCKET_URI="gs://acd-demo"

# %%
SERVICE_ACCOUNT="89959112353-compute@developer.gserviceaccount.com"
#SERVICE_ACCOUNT="562515424947-compute@developer.gserviceaccount.com"

# %%
! gsutil iam ch serviceAccount:{SERVICE_ACCOUNT}:roles/storage.objectCreator $BUCKET_URI
# !gsutil iam ch serviceAccount:{SERVICE_ACCOUNT}:roles/storage.objectViewer $BUCKET_URI

# %%
#!gsutil iam ch user:kirti@austincapitaldata.com:roles/storage.objectViewer gs://scholastic-genai
# Out:
# No changes made to gs://scholastic-genai/

# %%
#!gsutil iam ch user:kirti@austincapitaldata.com:roles/storage.objectViewer gs://acd-demo
# Out:
# No changes made to gs://acd-demo/

# %%
#! gsutil iam ch user:kirti@austincapitaldata.com:roles/storage.objectCreator $BUCKET_URI
# Out:
# No changes made to gs://acd-demo/

# %% [markdown]
# Import libraries and define constants:

# %%
import google.cloud.aiplatform as aiplatform
from vertexai.preview.language_models import (TextGenerationModel,
                                              TuningEvaluationSpec)

# %% [markdown]
# Initialize Vertex AI SDK for Python:
# - Initialize the Vertex AI SDK for Python for your project and corresponding bucket.

# %%
aiplatform.init(project=PROJECT_ID, location=REGION, staging_bucket=BUCKET_URI)

# %% [markdown]
# Load pretrained model:
# - Load the pretrained BISON model from Vertex AI LLM Model Garden.

# %%
model = TextGenerationModel.from_pretrained("google/text-bison@001")

model.list_tuned_model_names()
# Out:
# []

# %% [markdown]
# Tune the model:
#
# - Next, you tune the model using the `tune_model()` method, with the following parameters:
#
#  `training_data`: A pandas Dataframe or Cloud Storage location of the training data for tuning the model.<br>
# `learning_rate_multiplier`: A multiplier to apply to the recommended learning rate. To use the recommended learning rate, use 1.0. <br>
# `train_steps`: The number of steps to run for model tuning. The batch size varies by tuning location:<br>
# - us-central1 has a batch size of 8.
# - europe-west4 has a batch size of 24.<br>
#
# If there are 240 examples in a training dataset, in europe-west4, it takes 240 / 24 = 10 steps to process the entire dataset once. In us-central1, it takes 240 / 8 = 30 steps to process the entire dataset once. The default value is 300.<br>
#
# `tuning_job_location`: The region where the tuning job should be run. Supported regions are: `us-central1` and `europe-west4`.<br>
# `tuned_model_location`: The region where the tuned model should be deployed.

# %%
# !ls
# Out:
# sample_data  vaccinereviewTest.jsonl  vaccinereviewTrain.jsonl	vaccines-sentiment-analysis

# %%
! gsutil cp /content/vaccinereviewTrain.jsonl {BUCKET_URI}/vaccinereviewTrain.jsonl
! gsutil cp /content/vaccinereviewTest.jsonl {BUCKET_URI}/vaccinereviewTest.jsonl
# Out:
# Copying file:///content/vaccinereviewTrain.jsonl [Content-Type=application/octet-stream]...
# / [1 files][  1.8 MiB/  1.8 MiB]
# Operation completed over 1 objects/1.8 MiB.
# Copying file:///content/vaccinereviewTest.jsonl [Content-Type=application/octet-stream]...
# / [1 files][ 60.9 KiB/ 60.9 KiB]
# Operation completed over 1 objects/60.9 KiB.

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   input_text   7999 non-null   object
#  1   output_text  7999 non-null   object
# dtypes: object(2)
# memory usage: 125.1+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   input_text   256 non-null    object
#  1   output_text  256 non-null    object
# dtypes: object(2)
# memory usage: 4.1+ KB

# %%
# !pip install --upgrade google-auth
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.8/186.8 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.17.3
#     Uninstalling google-auth-2.17.3:
#       Successfully uninstalled google-auth-2.17.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# google-colab 1.0.0 requires google-auth==2.17.3, but you have google-auth 2.27.0 which is incompatible.
# ...

# %%
tuning_evaluation_spec = TuningEvaluationSpec(
    evaluation_data=f"{BUCKET_URI}/vaccinereviewTest.jsonl",
    evaluation_interval=20,
    enable_early_stopping=True,
)
model.tune_model(
    training_data=f"{BUCKET_URI}/vaccinereviewTrain.jsonl",
    # set to 1 for fast iteration and demo purpose. For this sample training dataset, we recommend at least 100 steps
    train_steps=100,
    learning_rate_multiplier=1.0,
    tuning_job_location="europe-west4",
    tuned_model_location="us-central1",  # Only us-central1 is supported
    model_display_name="test_model",
    tuning_evaluation_spec=tuning_evaluation_spec,
)
# Out:
# INFO:google.cloud.aiplatform.pipeline_jobs:Creating PipelineJob
# INFO:google.cloud.aiplatform.pipeline_jobs:PipelineJob created. Resource name: projects/89959112353/locations/europe-west4/pipelineJobs/tune-large-model-20240207184424
# INFO:google.cloud.aiplatform.pipeline_jobs:To use this PipelineJob in another session:
# INFO:google.cloud.aiplatform.pipeline_jobs:pipeline_job = aiplatform.PipelineJob.get('projects/89959112353/locations/europe-west4/pipelineJobs/tune-large-model-20240207184424')
# INFO:google.cloud.aiplatform.pipeline_jobs:View Pipeline Job:
# https://console.cloud.google.com/vertex-ai/locations/europe-west4/pipelines/runs/tune-large-model-20240207184424?project=89959112353
# INFO:google.cloud.aiplatform.pipeline_jobs:PipelineJob projects/89959112353/locations/europe-west4/pipelineJobs/tune-large-model-20240207184424 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# ...

# %%
# !gcloud iam roles describe
# Out:
# ERROR: (gcloud.iam.roles.describe) argument ROLE_ID: Must be specified.
# Usage: gcloud iam roles describe ROLE_ID [optional flags]
#   optional flags may be  --help | --organization | --project
#
# For detailed information on this command and its flags, run:
#   gcloud iam roles describe --help

# %% [markdown]
# Make a prediction with Vertex AI LLM:
# - Now, make a prediction using the predict() method from the Vertex AI LLM interface.

# %%
prompt ="Classify the sentiment of the following reviews  as positive, negative, or neutral towards vaccine.Text:user  amp 4 a vaccine given 2 healthy peeps fda think just not worth the ae risk unfortunately"

# %%
print(model.predict(prompt))
# Out:
# MultiCandidateTextGenerationResponse(text='negative', _prediction_response=Prediction(predictions=[{'citationMetadata': {'citations': []}, 'safetyAttributes': {'blocked': False, 'scores': [0.1, 0.2, 0.6, 0.9, 0.1, 0.2, 0.5, 0.1, 0.1, 0.5, 0.1, 0.1, 0.1], 'categories': ['Death, Harm & Tragedy', 'Derogatory', 'Finance', 'Health', 'Illicit Drugs', 'Insult', 'Legal', 'Politics', 'Public Safety', 'Religion & Belief', 'Sexual', 'Toxic', 'War & Conflict'], 'safetyRatings': [{'severityScore': 0.3, 'category': 'Dangerous Content', 'probabilityScore': 0.2, 'severity': 'LOW'}, {'probabilityScore': 0.2, 'severity': 'NEGLIGIBLE', 'category': 'Harassment', 'severityScore': 0.1}, {'severity': 'NEGLIGIBLE', 'severityScore': 0.2, 'probabilityScore': 0.2, 'category': 'Hate Speech'}, {'category': 'Sexually Explicit', 'severityScore': 0.1, 'severity': 'NEGLIGIBLE', 'probabilityScore': 0.1}]}, 'content': 'negative'}], deployed_model_id='', model_version_id='', model_resource_name='', explanations=None), 
# ...

# %% [markdown]
# Get the deployed Vertex AI Endpoint resource:
# - Next, get the Vertex AI Endpoint resource that the model was automatically deployed to.

# %%
endpoint = aiplatform.Endpoint(model._endpoint.resource_name)
print(endpoint)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-4d1c86a718ff> in <cell line: 1>()
# ----> 1 endpoint = aiplatform.Endpoint(model._endpoint.resource_name)
#       2 print(endpoint)
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/base.py in resource_name(self)
#     681     def resource_name(self) -> str:
#     682         """Full qualified resource name."""
# --> 683         self._assert_gca_resource_is_available()
#     684         return self._gca_resource.name
#     685
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/models.py in _assert_gca_resource_is_available(self)
#     281         asserting on gca_resource's availability."""
#     282         super()._assert_gca_resource_is_available()
# --> 283         self._sync_gca_resource_if_skipped()
#     284
#     285     @property
#
# ...
